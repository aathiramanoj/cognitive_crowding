# %%
# %tensorflow_version 1.x
import tensorflow as tf
print(tf.__version__)
# Out:
# TensorFlow 1.x selected.
# 1.15.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd  /content/drive/'My Drive'/NYU_Spring_2021/CCM/code/eccentricity
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/NYU_Spring_2021/CCM/code/eccentricity

# %%
# !chmod 755 -R src/python/ecc/ecc_train.py

# %%
pip install scipy==1.2.2
# Out:
# ...
#      |████████████████████████████████| 24.8MB 267kB/s
# ...
# ERROR: lucid 0.3.10 requires umap-learn, which is not installed.
# ERROR: lucid 0.3.10 has requirement numpy<=1.19, but you'll have numpy 1.19.5 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# ...

# %%
import os
import tensorflow as tf
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
# !src/python/ecc/ecc_train.py --parity=even --image_save_interval=1 --num_scales=5 --train_dir=experiments/demo-experiment/gen_0  --model_name=flanker_None
# Out:
# experiments/demo-experiment/gen_0/data/train_dh=120-flanker_h=120-train_ecc=0.0-ns=5-rs=False-p=even-ftype=0-te=0.0-fe=0.0-c=inf-fd=MNIST-cnorm=None-place=None.tfrecords
# WARNING:tensorflow:From /content/drive/My Drive/NYU_Spring_2021/CCM/code/eccentricity/src/python/ecc/convert_to_records.py:336: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# W0510 23:08:51.080001 140229289056128 deprecation.py:323] From /content/drive/My Drive/NYU_Spring_2021/CCM/code/eccentricity/src/python/ecc/convert_to_records.py:336: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# ...

# %%
# !ls
# Out:
# experiments  LICENSE  README.md  requirements.txt  src

# %%
# !ls experiments/demo-experiment/gen/images
# Out:
# 'dh=120-flanker_h=120-train_ecc=0.0-ns=5-rs=False-p=even-ftype=0-te=0.0-fe=0.0-c=inf-fd=MNIST-cnorm=None-place=None'

# %%
dh=120-flanker_h=120-train_ecc=0-ns=11-rs=True-p=even-ftype=0-te=0-fe=0-c=inf-fd=MNIST-cnorm=areafactor-place=None/train
gen/images/dh=120-flanker_h=120-train_ecc=0-ns=11-rs=False-p=even-ftype=1-te=120-fe=360-c=inf-fd=MNIST-cnorm=areafactor-place=None

# %%
# !python src/python/ecc/ecc_train.py --parity=even flanker_type=1 --flanker_ecc=360 --train_ecc=120 --learning_rate=0.01 --image_save_interval=10 --pm=5-1-1-1-1 --num_scales=5 --total_pool=True --train_dir=experiments/demo-experiment/gen_1  --contrast_norm=None  --model_name=5-1-1-1-1_total_pool_contrast_None_lr0.01
# Out:
# experiments/demo-experiment/gen_1/data/train_dh=120-flanker_h=120-train_ecc=0.0-ns=5-rs=False-p=even-ftype=0-te=0.0-fe=240.0-c=inf-fd=MNIST-cnorm=None-place=None.tfrecords
# WARNING:tensorflow:From /content/drive/My Drive/NYU_Spring_2021/CCM/code/eccentricity/src/python/ecc/convert_to_records.py:336: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# W0510 23:25:25.880391 140686298564480 deprecation.py:323] From /content/drive/My Drive/NYU_Spring_2021/CCM/code/eccentricity/src/python/ecc/convert_to_records.py:336: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# ...

# %%
# !python src/python/ecc/ecc_train.py --parity=even --learning_rate=0.01 --image_save_interval=10 --pm=5-1-1-1-1 --num_scales=5 --total_pool=True --train_dir=experiments/demo-experiment/gen_0  --contrast_norm=None  --model_name=5-1-1-1-1_total_pool_contrast_None_lr0.01
# Out:
# python3: can't open file 'src/python/ecc/ecc_train.py': [Errno 2] No such file or directory

# %%
# !python src/python/ecc/ecc_train.py --parity=even --flanker_type=1 --flanker_ecc=240 --target_ecc=120 --learning_rate=0.01 --image_save_interval=10 --pm=5-1-1-1-1 --num_scales=5 --total_pool=True --train_dir=experiments/demo-experiment/gen_fl_1  --contrast_norm=None  --model_name=5-1-1-1-1_total_pool_contrast_None_lr0.01
# Out:
# experiments/demo-experiment/gen_fl_1/data/train_dh=120-flanker_h=120-train_ecc=0.0-ns=5-rs=False-p=even-ftype=1-te=120.0-fe=240.0-c=inf-fd=MNIST-cnorm=None-place=None.tfrecords
# WARNING:tensorflow:From /content/drive/My Drive/NYU_Spring_2021/CCM/code/eccentricity/src/python/ecc/convert_to_records.py:338: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# W0511 01:41:04.240851 140282244945792 deprecation.py:323] From /content/drive/My Drive/NYU_Spring_2021/CCM/code/eccentricity/src/python/ecc/convert_to_records.py:338: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# ...

# %%
# !python src/python/ecc/ecc_train.py --parity=even --flanker_type=2 --flanker_ecc=480 --learning_rate=0.01 --image_save_interval=10 --pm=5-1-1-1-1 --num_scales=5 --total_pool=True --train_dir=experiments/demo-experiment/gen_fl_2  --contrast_norm=None  --model_name=5-1-1-1-1_total_pool_contrast_None_lr0.01
# Out:
# experiments/demo-experiment/gen_fl_2/data/train_dh=120-flanker_h=120-train_ecc=0.0-ns=5-rs=False-p=even-ftype=2-te=0.0-fe=480.0-c=inf-fd=MNIST-cnorm=None-place=None.tfrecords
# WARNING:tensorflow:From /content/drive/My Drive/NYU_Spring_2021/CCM/code/eccentricity/src/python/ecc/convert_to_records.py:338: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# W0511 02:26:21.612940 140362631219072 deprecation.py:323] From /content/drive/My Drive/NYU_Spring_2021/CCM/code/eccentricity/src/python/ecc/convert_to_records.py:338: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# ...

# %%
# !python src/python/ecc/ecc_train.py --parity=even --flanker_type=1 --flanker_ecc=480 --learning_rate=0.01 --image_save_interval=10 --pm=5-1-1-1-1 --num_scales=5 --total_pool=True --train_dir=experiments/demo-experiment/gen_fl_1_xa_480  --contrast_norm=None  --model_name=5-1-1-1-1_total_pool_contrast_None_lr0.01
# Out:
# experiments/demo-experiment/gen_fl_1_xa_480/data/train_dh=120-flanker_h=120-train_ecc=0.0-ns=5-rs=False-p=even-ftype=1-te=0.0-fe=480.0-c=inf-fd=MNIST-cnorm=None-place=None.tfrecords
# WARNING:tensorflow:From /content/drive/My Drive/NYU_Spring_2021/CCM/code/eccentricity/src/python/ecc/convert_to_records.py:338: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# W0511 09:56:54.827875 139882508433280 deprecation.py:323] From /content/drive/My Drive/NYU_Spring_2021/CCM/code/eccentricity/src/python/ecc/convert_to_records.py:338: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# ...

# %%
# !ls -d gen/images/*ftype=1*te=120*fe=360*
# !python src/python/ecc/ecc_train.py --parity=even --flanker_type=1 --flanker_ecc=360 --target_ecc=120 --learning_rate=0.01 --image_save_interval=1000 --pm=5-1-1-1-1 --num_scales=5 --total_pool=True --train_dir=experiments/demo-experiment/gen_fl_1_120  --contrast_norm=None  --model_name=5-1-1-1-1_total_pool_contrast_None_lr0.01
# Out:
# experiments/demo-experiment/gen_fl_1_120/data/train_dh=120-flanker_h=120-train_ecc=0.0-ns=5-rs=False-p=even-ftype=1-te=120.0-fe=360.0-c=inf-fd=MNIST-cnorm=None-place=None.tfrecords
# WARNING:tensorflow:From /content/drive/My Drive/NYU_Spring_2021/CCM/code/eccentricity/src/python/ecc/convert_to_records.py:338: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# W0512 08:29:56.670913 139910440990592 deprecation.py:323] From /content/drive/My Drive/NYU_Spring_2021/CCM/code/eccentricity/src/python/ecc/convert_to_records.py:338: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# ...

# %%
from matplotlib import pyplot as plt

# %%
base_net = [
99.26,
26.39,
24.015,
99.26,
99.26,
]
